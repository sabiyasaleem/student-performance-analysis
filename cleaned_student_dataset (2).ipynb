# %% [markdown]
# # Student Performance Data Cleaning Project
#
# ## Objective
# Clean and prepare student performance data for analysis using Pandas.
#
# ---
#
# ## Tools Used
# - Python
# - Pandas
# - Matplotlib
# - Jupyter Notebook

# %%
import pandas as pd

# Load dataset
file_path = "C:/Users/LOG IN/Desktop/Student_Performance_Project/data/data.csv"

student_df = pd.read_csv(file_path, sep=";", quotechar='"', encoding='latin1')

print("✅ Data Loaded Successfully")
student_df.head(20)
# Out:
# ✅ Data Loaded Successfully
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0      GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1      GP   F   17       U     GT3       T     1     1   at_home     other
# 2      GP   F   15       U     LE3       T     1     1   at_home     other
# 3      GP   F   15       U     GT3       T     4     2    health  services
# 4      GP   F   16       U     GT3       T     3     3     other     other
# 5      GP   M   16       U     LE3       T     4     3  services     other
# 6      GP   M   16       U     LE3       T     2     2     other     other
# 7      GP   F   17       U     GT3       A     4     4     other   teacher
# 8      GP   M   15       U     LE3       A     3     2  services     other
# 9      GP   M   15       U     GT3       T     3     4     other     other
# 10     GP   F   15       U     GT3       T     4     4   teacher    health
# 11     GP   F   15       U     GT3       T     2     1  services     other
# 12     GP   M   15       U     LE3       T     4     4    health  services
# 13     GP   M   15       U     GT3       T     4     3   teacher     other
# 14     GP   M   15       U     GT3       A     2     2     other     other
# 15     GP   F   16       U     GT3       T     4     4    health     other
# 16     GP   F   16       U     GT3       T     4     4  services  services
# 17     GP   F   16       U     GT3       T     3     3     other     other
# 18     GP   M   17       U     GT3       T     3     2  services  services
# 19     GP   M   16       U     LE3       T     4     3    health     other
#
#     ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0   ...      4        3      4     1     1      3        4   0  11  11
# 1   ...      5        3      3     1     1      3        2   9  11  11
# 2   ...      4        3      2     2     3      3        6  12  13  12
# 3   ...      3        2      2     1     1      5        0  14  14  14
# 4   ...      4        3      2     1     2      5        0  11  13  13
# 5   ...      5        4      2     1     2      5        6  12  12  13
# 6   ...      4        4      4     1     1      3        0  13  12  13
# 7   ...      4        1      4     1     1      1        2  10  13  13
# 8   ...      4        2      2     1     1      1        0  15  16  17
# 9   ...      5        5      1     1     1      5        0  12  12  13
# 10  ...      3        3      3     1     2      2        2  14  14  14
# 11  ...      5        2      2     1     1      4        0  10  12  13
# 12  ...      4        3      3     1     3      5        0  12  13  12
# 13  ...      5        4      3     1     2      3        0  12  12  13
# 14  ...      4        5      2     1     1      3        0  14  14  15
# 15  ...      4        4      4     1     2      2        6  17  17  17
# 16  ...      3        2      3     1     2      2       10  13  13  14
# 17  ...      5        3      2     1     1      4        2  13  14  14
# 18  ...      5        5      5     2     4      5        2   8   8   7
# 19  ...      3        1      3     1     3      5        6  12  12  12
#
# [20 rows x 33 columns]

# %% [markdown]
# ## Initial Data Inspection
# Understanding the structure and basic information of the dataset.

# %%
print(student_df.info())
print(student_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
#  19  nursery     649 non-null    object
#  20  higher      649 non-null    object
#  21  internet    649 non-null    object
#  22  romantic    649 non-null    object
#  23  famrel      649 non-null    int64
#  24  freetime    649 non-null    int64
#  25  goout       649 non-null    int64
#  26  Dalc        649 non-null    int64
#  27  Walc        649 non-null    int64
#  28  health      649 non-null    int64
#  29  absences    649 non-null    int64
#  30  G1          649 non-null    int64
#  31  G2          649 non-null    int64
#  32  G3          649 non-null    int64
# dtypes: int64(16), object(17)
# memory usage: 167.4+ KB
# None
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# std      0.955717    1.051093    1.175766    0.924834    1.284380    1.446259
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      4.000000    3.000000    2.000000    1.000000    1.000000    2.000000
# 50%      4.000000    3.000000    3.000000    1.000000    2.000000    4.000000
# 75%      5.000000    4.000000    4.000000    2.000000    3.000000    5.000000
# max      5.000000    5.000000    5.000000    5.000000    5.000000    5.000000
#
#          absences          G1          G2          G3
# count  649.000000  649.000000  649.000000  649.000000
# mean     3.659476   11.399076   11.570108   11.906009
# std      4.640759    2.745265    2.913639    3.230656
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000   10.000000   10.000000   10.000000
# 50%      2.000000   11.000000   11.000000   12.000000
# 75%      6.000000   13.000000   13.000000   14.000000
# max     32.000000   19.000000   19.000000   19.000000

# %%
student_df.rename(columns={
        "famsize":"family_size",
    "Pstatus":"parent_status",
    "Medu":"mother_education",
    "Fedu": "father_education",
    "Mjob": "mother_job",
    "Fjob":"father_job",
    "famsup":"family_support",
    "famrel": "family_relationship",
    "goout":"going_out",
    "Dalc":"daily_alcohol",
    "Walc":"weekly_alcohol",
    "G1":"first_period_grade",
   "G2":"second_period_grade",
    "G3": "final_grade"
    }, inplace=True)

# %%
for col in student_df.select_dtypes(include='object').columns:
    student_df[col] = student_df[col].astype(str).str.strip().str.strip('"').str.lower()

print("✅ Text Columns Cleaned")
# Out:
# ✅ Text Columns Cleaned

# %%
print(student_df.info())
print(student_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   school               649 non-null    object
#  1   sex                  649 non-null    object
#  2   age                  649 non-null    int64
#  3   address              649 non-null    object
#  4   family_size          649 non-null    object
#  5   parent_status        649 non-null    object
#  6   mother_education     649 non-null    int64
#  7   father_education     649 non-null    int64
#  8   mother_job           649 non-null    object
#  9   father_job           649 non-null    object
#  10  reason               649 non-null    object
#  11  guardian             649 non-null    object
#  12  traveltime           649 non-null    int64
#  13  studytime            649 non-null    int64
#  14  failures             649 non-null    int64
#  15  schoolsup            649 non-null    object
#  16  family_support       649 non-null    object
#  17  paid                 649 non-null    object
#  18  activities           649 non-null    object
#  19  nursery              649 non-null    object
#  20  higher               649 non-null    object
#  21  internet             649 non-null    object
#  22  romantic             649 non-null    object
#  23  family_relationship  649 non-null    int64
#  24  freetime             649 non-null    int64
#  25  going_out            649 non-null    int64
#  26  daily_alcohol        649 non-null    int64
#  27  weekly_alcohol       649 non-null    int64
#  28  health               649 non-null    int64
#  29  absences             649 non-null    int64
#  30  first_period_grade   649 non-null    int64
#  31  second_period_grade  649 non-null    int64
#  32  final_grade          649 non-null    int64
# dtypes: int64(16), object(17)
# memory usage: 167.4+ KB
# None
#               age  mother_education  father_education  traveltime   studytime  \
# count  649.000000        649.000000        649.000000  649.000000  649.000000
# mean    16.744222          2.514638          2.306626    1.568567    1.930663
# std      1.218138          1.134552          1.099931    0.748660    0.829510
# min     15.000000          0.000000          0.000000    1.000000    1.000000
# 25%     16.000000          2.000000          1.000000    1.000000    1.000000
# 50%     17.000000          2.000000          2.000000    1.000000    2.000000
# 75%     18.000000          4.000000          3.000000    2.000000    2.000000
# max     22.000000          4.000000          4.000000    4.000000    4.000000
#
#          failures  family_relationship    freetime   going_out  daily_alcohol  \
# count  649.000000           649.000000  649.000000  649.000000     649.000000
# mean     0.221880             3.930663    3.180277    3.184900       1.502311
# std      0.593235             0.955717    1.051093    1.175766       0.924834
# min      0.000000             1.000000    1.000000    1.000000       1.000000
# 25%      0.000000             4.000000    3.000000    2.000000       1.000000
# 50%      0.000000             4.000000    3.000000    3.000000       1.000000
# 75%      0.000000             5.000000    4.000000    4.000000       2.000000
# max      3.000000             5.000000    5.000000    5.000000       5.000000
#
#        weekly_alcohol      health    absences  first_period_grade  \
# count      649.000000  649.000000  649.000000          649.000000
# mean         2.280431    3.536210    3.659476           11.399076
# std          1.284380    1.446259    4.640759            2.745265
# min          1.000000    1.000000    0.000000            0.000000
# 25%          1.000000    2.000000    0.000000           10.000000
# 50%          2.000000    4.000000    2.000000           11.000000
# 75%          3.000000    5.000000    6.000000           13.000000
# max          5.000000    5.000000   32.000000           19.000000
#
#        second_period_grade  final_grade
# count           649.000000   649.000000
# mean             11.570108    11.906009
# std               2.913639     3.230656
# min               0.000000     0.000000
# 25%              10.000000    10.000000
# 50%              11.000000    12.000000
# 75%              13.000000    14.000000
# max              19.000000    19.000000

# %% [markdown]
# ## 🔢 Convert Numeric Columns
# Ensuring numeric data is properly formatted.

# %%
numeric_cols = [
"age", "mother_education", "father_education", "travel_time", "study_time", "past_failures", "family_relationship", "free_time", "going_out", "weekday_alcohol", "weekend_alcohol", "health_status", "absences", "first_period_grade", "second_period_grade", "final_grade"]


for col in numeric_cols:
    if col in student_df.columns:
        student_df[col] = pd.to_numeric(student_df[col], errors='coerce')

print("✅ Numeric Conversion Done")
# Out:
# ✅ Numeric Conversion Done

# %% [markdown]
# ## ❗ Handling Missing Values
# Removing rows with missing values.

# %%
print("Missing Values:\n", student_df.isnull().sum())

student_df.dropna(inplace=True)

print("✅ Missing Values Removed")
# Out:
# Missing Values:
#  school                 0
# sex                    0
# age                    0
# address                0
# family_size            0
# parent_status          0
# mother_education       0
# father_education       0
# mother_job             0
# father_job             0
# reason                 0
# guardian               0
# traveltime             0
# studytime              0
# failures               0
# schoolsup              0
# family_support         0
# paid                   0
# activities             0
# nursery                0
# higher                 0
# internet               0
# romantic               0
# family_relationship    0
# freetime               0
# going_out              0
# daily_alcohol          0
# weekly_alcohol         0
# health                 0
# absences               0
# first_period_grade     0
# second_period_grade    0
# final_grade            0
# dtype: int64
# ✅ Missing Values Removed

# %% [markdown]
# ## 🔁 Removing Duplicates

# %%
student_df.drop_duplicates(inplace=True)

print("✅ Duplicates Removed")
# Out:
# ✅ Duplicates Removed

# %% [markdown]
# ## 🔄 Standardizing Values

# %%
student_df['address'] = student_df['address'].replace({'u': 'urban', 'r': 'rural'})
student_df['school'] = student_df['school'].replace({
    'gp': 'gabriel pereira',
    'ms': 'mousinho da silveira'
})

print("✅ Values Standardized")
# Out:
# ✅ Values Standardized

# %%
print(student_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   school               649 non-null    object
#  1   sex                  649 non-null    object
#  2   age                  649 non-null    int64
#  3   address              649 non-null    object
#  4   family_size          649 non-null    object
#  5   parent_status        649 non-null    object
#  6   mother_education     649 non-null    int64
#  7   father_education     649 non-null    int64
#  8   mother_job           649 non-null    object
#  9   father_job           649 non-null    object
#  10  reason               649 non-null    object
#  11  guardian             649 non-null    object
#  12  traveltime           649 non-null    int64
#  13  studytime            649 non-null    int64
#  14  failures             649 non-null    int64
#  15  schoolsup            649 non-null    object
#  16  family_support       649 non-null    object
#  17  paid                 649 non-null    object
#  18  activities           649 non-null    object
#  19  nursery              649 non-null    object
#  20  higher               649 non-null    object
#  21  internet             649 non-null    object
#  22  romantic             649 non-null    object
#  23  family_relationship  649 non-null    int64
#  24  freetime             649 non-null    int64
#  25  going_out            649 non-null    int64
#  26  daily_alcohol        649 non-null    int64
#  27  weekly_alcohol       649 non-null    int64
#  28  health               649 non-null    int64
#  29  absences             649 non-null    int64
#  30  first_period_grade   649 non-null    int64
#  31  second_period_grade  649 non-null    int64
#  32  final_grade          649 non-null    int64
# dtypes: int64(16), object(17)
# memory usage: 167.4+ KB
# None

# %% [markdown]
# # Inspect dataset Shape and Data types

# %%
print("Shape:", student_df.shape)
print("\nData Types:\n", student_df.dtypes)
print("\nFull Info:")
student_df.info()
# Out:
# Shape: (649, 33)
#
# Data Types:
#  school                 object
# sex                    object
# age                     int64
# address                object
# family_size            object
# parent_status          object
# mother_education        int64
# father_education        int64
# mother_job             object
# father_job             object
# reason                 object
# guardian               object
# traveltime              int64
# studytime               int64
# failures                int64
# schoolsup              object
# family_support         object
# paid                   object
# activities             object
# nursery                object
# higher                 object
# internet               object
# romantic               object
# family_relationship     int64
# freetime                int64
# going_out               int64
# daily_alcohol           int64
# weekly_alcohol          int64
# health                  int64
# absences                int64
# first_period_grade      int64
# second_period_grade     int64
# final_grade             int64
# dtype: object
#
# Full Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   school               649 non-null    object
#  1   sex                  649 non-null    object
#  2   age                  649 non-null    int64
#  3   address              649 non-null    object
#  4   family_size          649 non-null    object
#  5   parent_status        649 non-null    object
#  6   mother_education     649 non-null    int64
#  7   father_education     649 non-null    int64
#  8   mother_job           649 non-null    object
#  9   father_job           649 non-null    object
#  10  reason               649 non-null    object
#  11  guardian             649 non-null    object
#  12  traveltime           649 non-null    int64
#  13  studytime            649 non-null    int64
#  14  failures             649 non-null    int64
#  15  schoolsup            649 non-null    object
#  16  family_support       649 non-null    object
#  17  paid                 649 non-null    object
#  18  activities           649 non-null    object
#  19  nursery              649 non-null    object
#  20  higher               649 non-null    object
#  21  internet             649 non-null    object
#  22  romantic             649 non-null    object
#  23  family_relationship  649 non-null    int64
#  24  freetime             649 non-null    int64
#  25  going_out            649 non-null    int64
#  26  daily_alcohol        649 non-null    int64
#  27  weekly_alcohol       649 non-null    int64
#  28  health               649 non-null    int64
#  29  absences             649 non-null    int64
#  30  first_period_grade   649 non-null    int64
#  31  second_period_grade  649 non-null    int64
#  32  final_grade          649 non-null    int64
# dtypes: int64(16), object(17)
# memory usage: 167.4+ KB

# %% [markdown]
# # 📊 Student Performance Analysis
#
# This project analyzes student performance using Python.
# We calculate average grades, identify high-performing students, and explore relationships between study habits and performance.

# %% [markdown]
# ##  1. Average Final Grade (G3)
#
# We calculate the average final grade of all students.

# %%
avg_g3 = student_df['final_grade'].mean()
print("Average Final Grade (final_grade):", avg_g3)
# Out:
# Average Final Grade (final_grade): 11.906009244992296

# %% [markdown]
# ## 🔹 2. Students Scoring Above 15
#
# We count how many students scored more than 15 marks.

# %%
students_above_15 = student_df[student_df['final_grade'] > 15].shape[0]
print("Number of students scoring above 15:", students_above_15)
# Out:
# Number of students scoring above 15: 82

# %% [markdown]
# ## 🔹 3. Study Time vs Performance
#
# We check if study time is related to student performance using correlation.

# %%
correlation = student_df['studytime'].corr(student_df['final_grade'])
print("Correlation between study time and final_grade:", correlation)

if correlation > 0.5:
    print("Strong positive relationship")
elif correlation > 0:
    print("Weak positive relationship")
elif correlation == 0:
    print("No relationship")
else:
    print("Negative relationship")
# Out:
# Correlation between study time and final_grade: 0.2497886899988628
# Weak positive relationship

# %% [markdown]
# ## 🔹 4. Gender Performance Comparison
#
# We compare the average performance of male and female students.

# %%
gender_avg = student_df.groupby('sex')['final_grade'].mean()
print("Average grade by gender:")
print(gender_avg)

best_gender = gender_avg.idxmax()
print("Better performing gender:", best_gender)
# Out:
# Average grade by gender:
# sex
# f    12.253264
# m    11.406015
# Name: final_grade, dtype: float64
# Better performing gender: f

# %% [markdown]
# ## Visualizations
#
# In this section, we visualize student performance using different plots:
# - Histogram of final grades
# - Scatter plot of study time vs grades
# - Bar chart comparing gender performance

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure()
plt.hist(student_df['final_grade'])
plt.title("Distribution of Final Grades (final_grade)")
plt.xlabel("Final Grade")
plt.ylabel("Number of Students")
plt.show()

# %% [markdown]
# ### 📊 Scatter Plot: Study Time vs Grades
#
# This plot shows the relationship between study time and final grades.

# %%
import seaborn as sns
plt.scatter(student_df['studytime'], student_df['final_grade'])
plt.title("Study Time vs Final Grade")
plt.xlabel("Study Time")
plt.ylabel("Final Grade (final_grade)")
plt.show()

# %% [markdown]
# ### 📊 Bar Chart: Gender vs Average Score
#
# This compares average performance between male and female students.

# %%
gender_avg = student_df.groupby('sex')['final_grade'].mean()

plt.figure()
gender_avg.plot(kind='bar')
plt.title("Average Grade by Gender")
plt.xlabel("Gender")
plt.ylabel("Average Final Grade (final_grade)")
plt.show()

# %%
print(type(student_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
student_df.style.set_properties(**{'text-align': 'center'})
# Out:
# <style type="text/css">
# #T_fa88b_row0_col0, #T_fa88b_row0_col1, #T_fa88b_row0_col2, #T_fa88b_row0_col3, #T_fa88b_row0_col4, #T_fa88b_row0_col5, #T_fa88b_row0_col6, #T_fa88b_row0_col7, #T_fa88b_row0_col8, #T_fa88b_row0_col9, #T_fa88b_row0_col10, #T_fa88b_row0_col11, #T_fa88b_row0_col12, #T_fa88b_row0_col13, #T_fa88b_row0_col14, #T_fa88b_row0_col15, #T_fa88b_row0_col16, #T_fa88b_row0_col17, #T_fa88b_row0_col18, #T_fa88b_row0_col19, #T_fa88b_row0_col20, #T_fa88b_row0_col21, #T_fa88b_row0_col22, #T_fa88b_row0_col23, #T_fa88b_row0_col24, #T_fa88b_row0_col25, #T_fa88b_row0_col26, #T_fa88b_row0_col27, #T_fa88b_row0_col28, #T_fa88b_row0_col29, #T_fa88b_row0_col30, #T_fa88b_row0_col31, #T_fa88b_row0_col32, #T_fa88b_row1_col0, #T_fa88b_row1_col1, #T_fa88b_row1_col2, #T_fa88b_row1_col3, #T_fa88b_row1_col4, #T_fa88b_row1_col5, #T_fa88b_row1_col6, #T_fa88b_row1_col7, #T_fa88b_row1_col8, #T_fa88b_row1_col9, #T_fa88b_row1_col10, #T_fa88b_row1_col11, #T_fa88b_row1_col12, #T_fa88b_row1_col13, #T_fa88b_row1_col14, #T_fa88b_row1_col15, #T_fa88b_row1_col16, #T_fa88b_row1_col17, #T_fa88b_row1_col18, #T_fa88b_row1_col19, #T_fa88b_row1_col20, #T_fa88b_row1_col21, #T_fa88b_row1_col22, #T_fa88b_row1_col23, #T_fa88b_row1_col24, #T_fa88b_row1_col25, #T_fa88b_row1_col26, #T_fa88b_row1_col27, #T_fa88b_row1_col28, #T_fa88b_row1_col29, #T_fa88b_row1_col30, #T_fa88b_row1_col31, #T_fa88b_row1_col32, #T_fa88b_row2_col0, #T_fa88b_row2_col1, #T_fa88b_row2_col2, #T_fa88b_row2_col3, #T_fa88b_row2_col4, #T_fa88b_row2_col5, #T_fa88b_row2_col6, #T_fa88b_row2_col7, #T_fa88b_row2_col8, #T_fa88b_row2_col9, #T_fa88b_row2_col10, #T_fa88b_row2_col11, #T_fa88b_row2_col12, #T_fa88b_row2_col13, #T_fa88b_row2_col14, #T_fa88b_row2_col15, #T_fa88b_row2_col16, #T_fa88b_row2_col17, #T_fa88b_row2_col18, #T_fa88b_row2_col19, #T_fa88b_row2_col20, #T_fa88b_row2_col21, #T_fa88b_row2_col22, #T_fa88b_row2_col23, #T_fa88b_row2_col24, #T_fa88b_row2_col25, #T_fa88b_row2_col26, #T_fa88b_row2_col27, #T_fa88b_row2_col28, #T_fa88b_row2_col29, #T_fa88b_row2_col30, #T_fa88b_row2_col31, #T_fa88b_row2_col32, #T_fa88b_row3_col0, #T_fa88b_row3_col1, #T_fa88b_row3_col2, #T_fa88b_row3_col3, #T_fa88b_row3_col4, #T_fa88b_row3_col5, #T_fa88b_row3_col6, #T_fa88b_row3_col7, #T_fa88b_row3_col8, #T_fa88b_row3_col9, #T_fa88b_row3_col10, #T_fa88b_row3_col11, #T_fa88b_row3_col12, #T_fa88b_row3_col13, #T_fa88b_row3_col14, #T_fa88b_row3_col15, #T_fa88b_row3_col16, #T_fa88b_row3_col17, #T_fa88b_row3_col18, #T_fa88b_row3_col19, #T_fa88b_row3_col20, #T_fa88b_row3_col21, #T_fa88b_row3_col22, #T_fa88b_row3_col23, #T_fa88b_row3_col24, #T_fa88b_row3_col25, #T_fa88b_row3_col26, #T_fa88b_row3_col27, #T_fa88b_row3_col28, #T_fa88b_row3_col29, #T_fa88b_row3_col30, #T_fa88b_row3_col31, #T_fa88b_row3_col32, #T_fa88b_row4_col0, #T_fa88b_row4_col1, #T_fa88b_row4_col2, #T_fa88b_row4_col3, #T_fa88b_row4_col4, #T_fa88b_row4_col5, #T_fa88b_row4_col6, #T_fa88b_row4_col7, #T_fa88b_row4_col8, #T_fa88b_row4_col9, #T_fa88b_row4_col10, #T_fa88b_row4_col11, #T_fa88b_row4_col12, #T_fa88b_row4_col13, #T_fa88b_row4_col14, #T_fa88b_row4_col15, #T_fa88b_row4_col16, #T_fa88b_row4_col17, #T_fa88b_row4_col18, #T_fa88b_row4_col19, #T_fa88b_row4_col20, #T_fa88b_row4_col21, #T_fa88b_row4_col22, #T_fa88b_row4_col23, #T_fa88b_row4_col24, #T_fa88b_row4_col25, #T_fa88b_row4_col26, #T_fa88b_row4_col27, #T_fa88b_row4_col28, #T_fa88b_row4_col29, #T_fa88b_row4_col30, #T_fa88b_row4_col31, #T_fa88b_row4_col32, #T_fa88b_row5_col0, #T_fa88b_row5_col1, #T_fa88b_row5_col2, #T_fa88b_row5_col3, #T_fa88b_row5_col4, #T_fa88b_row5_col5, #T_fa88b_row5_col6, #T_fa88b_row5_col7, #T_fa88b_row5_col8, #T_fa88b_row5_col9, #T_fa88b_row5_col10, #T_fa88b_row5_col11, #T_fa88b_row5_col12, #T_fa88b_row5_col13, #T_fa88b_row5_col14, #T_fa88b_row5_col15, #T_fa88b_row5_col16, #T_fa88b_row5_col17, #T_fa88b_row5_col18, #T_fa88b_row5_col19, #T_fa88b_row5_col20, #T_fa88b_row5_col21, #T_fa88b_row5_col22, #T_fa88b_row5_col23, #T_fa88b_row5_col24, #T_fa88b_row5_col25, #T_fa88b_row5_col26, #T_fa88b_row5_col27, #T_fa88 ...

# %% [markdown]
# # Average Final Grade

# %%
student_df['final_grade'].mean()
# Out:
# np.float64(11.906009244992296)

# %% [markdown]
# # Pass Rate

# %%
(student_df['final_grade'] >= 10).mean() * 100
# Out:
# np.float64(84.59167950693374)

# %% [markdown]
# # Fail Rate

# %%
(student_df['final_grade'] < 10).mean() * 100
# Out:
# np.float64(15.408320493066254)

# %% [markdown]
# # Top Performers Percentage

# %%
(student_df['final_grade'] > 15).mean() *100
# Out:
# np.float64(12.63482280431433)

# %%
student_df.to_csv("Cleaned_student_dataset.csv")
